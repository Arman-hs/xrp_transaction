# %%
"""
Minimal Example
===============
Generating a square wordcloud from the US constitution using default arguments.
"""
from os import path

from persian_wordcloud.wordcloud import PersianWordCloud, add_stop_words


text = open(path.join('', 'cloud_log.previous.txt'), encoding='utf-8').read()

# Add another stopword
stopwords = add_stop_words(['کاسپین'])
# add_stop_words

# %%
# Generate a word cloud image
wordcloud = PersianWordCloud(

).generate(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_20844/3890688456.py in <module>
#       1 # Generate a word cloud image
# ----> 2 wordcloud = PersianWordCloud(
#       3     only_persian=False,
#       4     max_words=100,
#       5     stopwords=stopwords,
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     611         self
#     612         """
# --> 613         words = self.process_text(text)
#     614         self.generate_from_frequencies(words)
#     615         return self
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/persian_wordcloud/wordcloud.py in process_text(self, text)
#     120
#     121         if self.collocations:
# --> 122             word_counts = unigrams_and_bigrams(words, self.normalize_plurals)
#     123         else:
#     124             word_counts, _ = process_tokens(words, self.normalize_plurals)
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/wordcloud/tokenization.py in unigrams_and_bigrams(words, stopwords, normalize_plurals, collocation_threshold)
#      41     # "thank much" from "thank you very much".
#      42     # We don't allow any of the words in the bigram to be stopwords
# ---> 43     bigrams = list(p for p in pairwise(words) if not any(w.lower() in stopwords for w in p))
#      44     unigrams = list(w for w in words if w.lower() not in stopwords)
#      45     n_words = len(unigrams)
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/wordcloud/tokenization.py in <genexpr>(.0)
#      41     # "thank much" from "thank you very much".
#      42     # We don't allow any of the words in the bigram to be stopwords
# ---> 43     bigrams = list(p for p in pairwise(words) if not any(w.lower() in stopwords for w in p))
#      44     unigrams = list(w for w in words if w.lower() not in stopwords)
#      45     n_words = len(unigrams)
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/wordcloud/tokenization.py in <genexpr>(.0)
#      41     # "thank much" from "thank you very much".
#      42     # We don't allow any of the words in the bigram to be stopwords
# ---> 43     bigrams = list(p for p in pairwise(words) if not any(w.lower() in stopwords for w in p))
#      44     unigrams = list(w for w in words if w.lower() not in stopwords)
#      45     n_words = len(unigrams)
#
# TypeError: argument of type 'bool' is not iterable

# %%
image = wordcloud.to_image()
image.show()
image.save('result.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_20844/294205985.py in <module>
#      16
#      17 # Generate a word cloud image
# ---> 18 wordcloud = PersianWordCloud(
#      19     only_persian=True,
#      20     max_words=100,
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/persian_wordcloud/wordcloud.py in generate(self, text)
#     143         # reshape persian words
#     144         text = get_display(arabic_reshaper.reshape(text))
# --> 145         return self.generate_from_text(text)
#     146
#     147     @staticmethod
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     611         self
#     612         """
# --> 613         words = self.process_text(text)
#     614         self.generate_from_frequencies(words)
#     615         return self
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/persian_wordcloud/wordcloud.py in process_text(self, text)
#     120
#     121         if self.collocations:
# --> 122             word_counts = unigrams_and_bigrams(words, self.normalize_plurals)
#     123         else:
#     124             word_counts, _ = process_tokens(words, self.normalize_plurals)
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/wordcloud/tokenization.py in unigrams_and_bigrams(words, stopwords, normalize_plurals, collocation_threshold)
#      41     # "thank much" from "thank you very much".
#      42     # We don't allow any of the words in the bigram to be stopwords
# ---> 43     bigrams = list(p for p in pairwise(words) if not any(w.lower() in stopwords for w in p))
#      44     unigrams = list(w for w in words if w.lower() not in stopwords)
#      45     n_words = len(unigrams)
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/wordcloud/tokenization.py in <genexpr>(.0)
#      41     # "thank much" from "thank you very much".
#      42     # We don't allow any of the words in the bigram to be stopwords
# ---> 43     bigrams = list(p for p in pairwise(words) if not any(w.lower() in stopwords for w in p))
#      44     unigrams = list(w for w in words if w.lower() not in stopwords)
#      45     n_words = len(unigrams)
#
# ~/anaconda3/envs/XRP/lib/python3.8/site-packages/wordcloud/tokenization.py in <genexpr>(.0)
#      41     # "thank much" from "thank you very much".
#      42     # We don't allow any of the words in the bigram to be stopwords
# ---> 43     bigrams = list(p for p in pairwise(words) if not any(w.lower() in stopwords for w in p))
#      44     unigrams = list(w for w in words if w.lower() not in stopwords)
#      45     n_words = len(unigrams)
#
# TypeError: argument of type 'bool' is not iterable
